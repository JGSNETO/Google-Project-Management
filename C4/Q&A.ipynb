# %% [markdown]
# # M2
#
# ====================
# SET 1
# ====================
# Q1: As a project manager, you conduct a process to determine which standards of quality are relevant to the project and how to satisfy them. Which quality management concept does this describe?
# A: Quality planning ✅
#
# Q2: Which quality management concept—often set at the beginning of a project—uses multiple guidelines, such as reliability and usability, to ensure its desired outcome?
# A: Quality standards ✅
#
# Q3: As a project manager, you and your team monitor project results and delivery to determine if the desired results are being met. If issues are identified, you take corrective action to resolve them. Which quality management concept does this describe?
# A: Quality control ✅
#
# Q4: As a project manager, you and your team conduct a review process. Your goal is to evaluate whether the project is moving toward delivering a high-quality service or product and to prevent defects before they occur. Which quality management concept does this describe?
# A: Quality assurance ✅
#
# ====================
# SET 2
# ====================
# Q1: A project manager should ask open-ended questions when utilizing which of the following three interpersonal skills?
# A: Empathetic listening ✅
#
# Q2: When is an optimal time to send out a feedback survey?
# A: Both before and after a product or service launches ✅
#
# Q3: What are the main goals of a user acceptance test (UAT)?
# A:
# - To identify issues that need to be addressed before considering the project to be done ✅
# - To demonstrate that the product, service, or process is behaving in expected ways in real-world scenarios ✅
# - To confirm that the product, service, or process is working as intended ✅
#
# Q4: As a project manager running a user acceptance test (UAT), you take your users through a sequence of steps to accomplish tasks in your product. What is the term for these steps?
# A: Critical user journey (test cases) ✅
#
# Q5: Which of the following are best practices for running an effective UAT?
# A:
# - Write UAT scripts based on user stories ✅
# - Create test cases for each item being tested ✅
# - Define and write down the acceptance criteria ✅
#
# ====================
# SET 3
# ====================
# Q1: _____ is an ongoing effort to improve products or services. It begins with a project manager recognizing processes and tasks that they should create, eliminate, or improve.
# A: Continuous improvement ✅
#
# Q2: A continuous improvement framework step involves conducting performance metrics and data collection to establish baselines. Which framework does this describe?
# A: DMAIC ✅
#
# Q3: Scenario: Plan strategies, Do (implement), Check results, Act (review). Which framework?
# A: PDCA ✅
#
# Q4: What’s the main difference between a program and a portfolio?
# A: A program is a collection of projects, whereas a portfolio is a collection of both projects and programs across an entire organization ✅
#
# Q5: A construction company tests a strategy to reduce costs across several projects as part of a long-term objective. Who oversees this?
# A: Portfolio manager ✅
#
# ====================
# SET 4
# ====================
# Q1: A project manager sends an anonymous team survey, asks for “we” language, and ends with lessons for future work. Which retrospective best practices are they following?
# A:
# - Don’t focus only on the negative ✅
# - Be blameless with teammates ✅
# - Change perspective ✅
#
# Q2: What are the main purposes of a retrospective?
# A:
# - Facilitate improved collaboration ✅
# - Encourage team-building ✅
# - Promote positive changes ✅
#
# Q3: Typical reasons for holding a retrospective?
# A:
# - Missed deadlines or expectations ✅
# - Delivered a new product ✅
# - Reached the end of a Sprint ✅
#
# Q4: Fill in the blank: The way you choose to structure your retrospective will depend on _____.
# A: your team and workplace ✅
#
# ====================
# SET 5
# ====================
# Q1: Meeting with customers to determine product and usability standards. Which quality concept?
# A: Quality standards ✅
#
# Q2: Step where PM asks “How will I determine if the quality measures lead to success?”
# A: Quality planning ✅
#
# Q3: To receive authentic and honest feedback from customers, what strategy should a PM use?
# A: Ask open-ended questions and listen to the customer’s current vs. desired state ✅
#
# Q4: In UAT, you create steps with expected results for each item tested. Which practice?
# A: Create test cases ✅
#
# Q5: A PM engages in continuous improvement to enhance team performance. What’s the purpose?
# A: To enable process improvement ✅
#
# Q6: Using DMAIC, you identify resources and write a project timeline. Which step?
# A: Define ✅
#
# Q7: In PDCA, first step when fixing a problem?
# A: Identify the root cause and brainstorm solutions ✅
#
# Q8: Which parts of a company rely on continuous improvement?
# A: Programs ✅, Projects ✅, Portfolios ✅
#
# Q9: A team delivers a feature but misses the deadline. What should the PM do?
# A: Hold a retrospective ✅
#
# Q10: During a sprint, disagreement with another team caused a missed deadline. What should PM do?
# A: Get everyone on the team together and discuss what happened ✅
#
# ====================
# SET 6
# ====================
# Q1: PM overseeing product launch, performing audits and check-ins to confirm quality. Which concept?
# A: Quality assurance ✅
#
# Q2: Step where PM asks: “How will I determine success?”
# A: Quality planning ✅
#
# Q3: PM listens to a frustrated customer, addresses concerns, and finds a win-win solution. Which skill?
# A: Empathetic listening ✅
#
# Q4: UAT with steps + expected results. Which practice?
# A: Create test cases ✅
#
# Q5: Experiment-related term for the unchanged process?
# A: Control group ✅
#
# Q6: DMAIC “Analyze” step involves?
# A: Identify the root cause of a problem and better understand the impact ✅
#
# Q7: PDCA step where PM implements the solution?
# A: Do ✅
#
# Q8: Program manager and portfolio manager scale efficient processes across projects. This exemplifies?
# A: Continuous improvement ✅
#
# Q9: A team delivers but misses a deadline. What should PM do?
# A: Hold a retrospective ✅
#
# Q10: Which way must a PM conduct a retrospective?
# A: There is no way which must be followed, it entirely depends on your team and workplace ✅

# %% [markdown]
# # M3
#
# ====================
# DATA AND STORYTELLING SET 1
# ====================
# Q1: As a project manager, you collect opinion-based feedback surveys in a text format as part of an effort to improve a product. What do you call this type of data?
# A: Qualitative data ✅
#
# Q2: As a project manager, you track the number of open and closed tasks per team member. What do you call this type of data?
# A: Quantitative data ✅
#
# Q3: How can a project manager help ensure the privacy of data collected from users, stakeholders, and others?
# A:
# - Anonymize data ✅
# - Increase data privacy awareness ✅
# - Use security tools ✅
#
# Q4: During the _____ step of the data analysis process, you collect and store the data you will analyze.
# A: Prepare ✅
#
# ====================
# STORYTELLING SET 2
# ====================
# Q1: When crafting a story, what is the first step a project manager takes to think like the people they are presenting to?
# A: Define the audience ✅
#
# Q2: During what storytelling step does a project manager design an infographic or chart to present the data?
# A: Choose a visual representation ✅
#
# Q3: During what storytelling step does a project manager vet data for credibility?
# A: Filter and analyze the data ✅
#
# Q4: When turning data into a story, a project manager first defines their audience. What is the second step?
# A: Collect the data ✅
#
# ====================
# DATA METRICS & VISUALIZATION SET 3
# ====================
# Q1: Goal of collecting data on the best selling product of the month to place new orders?
# A: To better understand user preferences and performance ✅
#
# Q2: Total time it takes to complete a project from start to finish?
# A: Duration ✅
#
# Q3: Managing a conference: increase in attendees by 200. What type of metric?
# A: Projection ✅
#
# Q4: Observable change that helps determine health of a project?
# A: Signal ✅
#
# Q5: _____ data are qualities or things that can’t be measured numerically.
# A: Qualitative ✅
#
# Q6: _____ is the process of turning facts into a narrative to communicate something.
# A: Storytelling ✅
#
# Q7: Type of chart to measure time against work done and remaining?
# A: Burndown charts ✅
#
# Q8: How many seconds should a viewer understand a presentation slide?
# A: One ✅
#
# Q9: Ensuring team awareness of data security and privacy protocols.
# A: Increasing privacy awareness ✅
#
# Q10: Reviewing, transforming, and organizing data, then creating graphs.
# A: Process ✅
#
# Q11: Gathering data from reputable sources for a story.
# A: Find the data ✅
#
# Q12: Demonstrating relationships between two variables with dots.
# A: Scatter plot ✅
#
# ====================
# DATA ANALYSIS & STORYTELLING SET 4
# ====================
# Q1: Goal of collecting data on best selling products?
# A: To better understand user preferences and performance ✅
#
# Q2: Total time to complete a project?
# A: Duration ✅
#
# Q3: When PM determines how long a project will take based on resources?
# A: Prediction ✅
#
# Q4: Observable change indicating project health?
# A: Signal ✅
#
# Q5: Process of collecting and organizing info to draw conclusions?
# A: Data analysis ✅
#
# Q6: Fifth stage in storytelling, tying all data and visuals into a cohesive narrative?
# A: Shaping the story ✅
#
# Q7: Why use visual representations of data?
# A:
# - To filter info and highlight important data ✅
# - To summarize info into a single representation ✅
# - To help viewer make sense and remember info ✅
#
# Q8: Ways to be flexible during a presentation?
# A:
# - Imagine and prepare for possible objections ✅
# - Identify and come up with answers to potential questions ✅
# - Practice to avoid mistakes that distract from your message ✅
#
# Q9: Avoid interpreting data to support pre-existing beliefs. This avoids which bias?
# A: Confirmation bias ✅
#
# Q10: Reviewing, transforming, organizing, and graphing data?
# A: Process ✅
#
# Q11: Asking if content is credible, skewed, or can be eliminated. Step?
# A: Filter and analyze the data ✅
#
# Q12: Scatter plot pattern line representing data?
# A: Trend line ✅

# %% [markdown]
# # M4
#
# ====================
# TEAM EFFECTIVENESS SET
# ====================
# Q1: Which of the following are true of teams?
# A:
# - They foster creativity ✅
# - They collaborate to solve problems in service of a shared goal ✅
# - They encourage accountability ✅
#
# Q2: Which of the five factors that impact team effectiveness is the most important?
# A: Psychological safety ✅
#
# Q3: Frequently requesting task updates; you create a process for team members to update their task status in daily chat. Aspect demonstrated?
# A: Create systems that turn chaos into order ✅
#
# Q4: How can PMs appreciate a team’s hard work after milestones?
# A: Schedule a team meeting to go out for lunch ✅
#
# Q5: Responsibilities during the forming stage of team development?
# A:
# - Provide context about the project ✅
# - Clarify project roles and goals ✅
# - Establish new team norms ✅
#
# Q6: New feedback system promoting honesty, respect, and integrity demonstrates which leadership quality?
# A: Ethical leadership ✅
#
# Q7: PM writing to another firm’s CEO about mutual benefits and projected sales. Steps of effective influencing?
# A:
# - Provide evidence ✅
# - Establish credibility ✅
# - Frame for common ground ✅
#
# Q8: PM improves ability to communicate with team and focuses on approach with an audience. Personal source of power improved?
# A: Expressiveness ✅
#
# Q9: Steps in ethical decision-making framework (Markkula Center)?
# A:
# - Get the facts ✅
# - Weigh the benefits ✅
# - Evaluate alternative actions ✅
# - Recognize an ethical issue ✅
#
# Q10: Providing air cover for your team while getting feedback. Best options?
# A:
# - Select two trusted team members to discuss the issue ✅
# - Hold an urgent meeting with all team members to discuss the issue ✅
#
# ====================
# TEAM DEVELOPMENT SET
# ====================
# Q1: Two team members disagree, you listen and propose a compromise. Which stage of team development?
# A: Storming ✅
#
# Q2: Delegating confidently to operations coordinator to resolve an issue. Stage?
# A: Performing ✅
#
# Q3: Team hasn’t worked together before, scheduling lunch to get acquainted. Stage?
# A: Forming ✅
#
# Q4: Introducing a new process that team quickly adopts. Stage?
# A: Norming ✅
#
# Q5: Managing team dynamics – responsibilities of PM?
# A:
# - Understand how to motivate the team ✅
# - Create a safe and collaborative environment ✅
# - Forge a consensus and set clear goals ✅
#
# ====================
# TEAM EFFECTIVENESS FACTORS SET
# ====================
# Q1: Five factors with greatest impact on team effectiveness?
# A: Psychological safety, dependability, structure and clarity, meaning, and impact ✅
#
# Q2: Teams that feel psychological safety – true statements?
# A:
# - Team members feel comfortable taking risks ✅
# - Team members are comfortable resolving interpersonal conflict ✅
# - Team members know they can seek different opinions ✅
#
# Q3: Key factor involving setting, negotiating, and meeting expectations?
# A: Dependability ✅
#
# Q4: Key factor providing clear sense of roles, plans, goals, and how work affects the group?
# A: Structure and clarity ✅
#
# Q5: How does a team’s sense of meaning impact effectiveness?
# A: Teams find a sense of purpose in their work or its results ✅
#
# ====================
# INFLUENCING SCENARIO SET
# ====================
# Q1: Ready to compare email to Conger’s four influencing mistakes?
# A: I’m ready! ✅
#
# Q2: Describe influencing mistakes in the Web Solutions email.
# A: The email approaches aggressively, resists compromise, fails to establish credibility or connect emotionally, and assumes one conversation is enough. ✅
#
# Q3: Ready to apply effective influencing steps to BookEnds scenario?
# A: I’m ready! ✅
#
# Q4: Sample email using Conger’s four steps:
# A:
#
# ---
# Subject: Ensuring the Best Experience for BookEnds Customers
#
# Dear Keiko,
#
# Thank you for sharing your concerns about the new website features. I understand that making changes to the checkout process and product suggestions may feel unfamiliar, and I want to ensure the site feels intuitive for your customers. Based on our decade of experience designing e-commerce sites, similar features we implemented for other bookstores have increased sales by 20% within six months while improving customer satisfaction. Our goal is to streamline the shopping experience while highlighting books your customers will love, so they feel excited and confident when making purchases. I would love to discuss any adjustments together to make sure the design meets both your expectations and your customers’ needs.
#
# Best regards,
# [Your Name]
# Project Manager, Web Solutions ✅
# ---

# %% [markdown]
# # M5
#
# ====================
# COMMUNICATION TOOLS & BEST PRACTICES SET 1
# ====================
# Q1: How should a project team communicate?
# A: The project team should communicate regularly and in various ways ✅
#
# Q2: Which communication tool could a PM use to create a project tracking report?
# A: Asana ✅
#
# Q3: Benefits of communication tools for PMs and teams?
# A:
# - They provide clarity and consistency of project details like key dates, tasks, and milestones ✅
# - They offer various ways to properly format communication ✅
#
# Q4: Information to include in the subject field of an email?
# A:
# - Whether the email requires an immediate response ✅
# - What the email is about ✅
# - Whether the email is urgent ✅
#
# ====================
# MEETINGS & AGENDA SET
# ====================
# Q1: For a PM to organize an effective meeting, they must carefully select attendees and prioritize topics in a(n) _____.
# A: agenda ✅
#
# Q2: Statements that best describe effective meetings?
# A: They are structured, intentional, collaborative, and inclusive ✅
#
# Q3: Actions to ensure productivity during a meeting?
# A:
# - Capture key points, action items, and decisions ✅
# - Encourage participation ✅
# - Determine the need for the meeting ✅
# - Prepare an agenda ✅
# - Practice and demonstrate active listening ✅
# - Email a recap of key decisions to participants ✅
#
# Q4: Why is it important to state a meeting’s purpose and expectations in the agenda?
# A:
# - To keep participants focused on the right topics ✅
# - To ensure everyone understands why they’re attending ✅
# - To help meeting attendees prepare ✅
#
# ====================
# COMMUNICATION RESPONSIBILITIES & INCLUSIVITY SET
# ====================
# Q1: Who is ultimately responsible for coordinating incoming and outgoing communication?
# A: The project manager ✅
#
# Q2: Tool to track team assignments and status updates?
# A: A work management tool like Asana ✅
#
# Q3: Best practice to respect team member’s time and keep meetings on track?
# A: Select only relevant team members to invite ✅
#
# Q4: Key component of inclusivity in meetings and presentations?
# A: accessible ✅
#
# Q5: Key reasons to meet with stakeholders?
# A:
# - To make a decision or resolve a major issue ✅
# - To present a project update ✅
# - To seek out and listen to feedback ✅
#
# Q6: Email best practice when removing excess content?
# A: Keep content concise ✅
#
# Q7: Ways to create an inclusive team environment in meetings?
# A:
# - Give everyone your full attention ✅
# - Formalize initial check-ins for the group ✅
# - Use images that reflect the diversity of the world ✅
#
# Q8: Best practice for recurring meetings across time zones?
# A: Alternate the meeting time across time zones so all team members feel equal priority ✅
#
# Q9: Items to discuss during a status update meeting?
# A: Change in the scope and quality of a project task ✅
#
# Q10: Meeting to review team performance and celebrate project completion?
# A: Retrospective ✅

# %% [markdown]
# # M6
# ====================
# PROJECT CLOSURE & TYPES SET
# ====================
# Q1: Criteria that must be met to close a project?
# A:
# - Project work has been completed ✅
# - Key stakeholders have acknowledged and agreed that the project is complete ✅
# - Agreed-upon project management processes have been executed ✅
#
# Q2: Types of projects PMs should avoid?
# A:
# - Abandoned projects ✅
# - Never-ending projects ✅
#
# Q3: Project with incomplete handoff resulting in a final deliverable never reaching the customer?
# A: Abandoned project ✅
#
# Q4: Project where deliverables and tasks cannot be completed?
# A: Never-ending project ✅
#
# ====================
# PROJECT CLOSEOUT & LESSONS LEARNED SET
# ====================
# Q1: First step of the closeout process after team completes required tasks?
# A: The project manager can review all tasks to assure the work is completed and no tasks were missed ✅
#
# Q2: Steps to ensure a project is closed?
# A:
# - Ensure all agreed upon project management processes are complete ✅
# - Get formal recognition from stakeholders that the project is done ✅
# - Confirm all tasks and work are complete ✅
#
# Q3: Step skipped if closeout report wasn’t compiled?
# A: Put together closing documentation, such as creating closeout reports ✅
#
# Q4: Closeout report section explaining what went well and what went wrong?
# A: Lessons learned ✅
#
# Q5: Purpose of impact report?
# A: Demonstrate how the project went and discuss the impact of its product or service ✅
#
# Q6: Steps for effective closing process?
# A:
# - The project manager gives the stakeholders an impact reporting presentation ✅
# - The project manager confirms the work is done and the agreed-upon closing processes are executed ✅
# - The project manager hosts a retrospective meeting for the team ✅
#
# Q7: A retrospective is the best tool for reflection and _____?
# A: improvement ✅
#
# Q8: Impacts of neglecting project closeout?
# A:
# - Negatively impact scheduled launch dates ✅
# - Damage your relationship with the customer or client ✅
# - Put your organization at legal risk ✅
#
# Q9: Questions lessons learned section should answer?
# A:
# - What was the process ✅
# - What went wrong ✅
# - What were the problem areas ✅
# - What went well ✅
#
# Q10: Stage of closing process when retrospectives are done?
# A:
# - At major completions or milestones ✅
# - At the end of a project ✅
